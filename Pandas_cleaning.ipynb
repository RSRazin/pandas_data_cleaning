# %% [markdown]
# # Shahadat Hossain Razin
# **Department of Statistics, Mobile- 01515237158, Email- razinstatiu@gmail.com**

# %% [markdown]
# # Pandas - Cleaning Data

# %% [markdown]
# **Data Cleaning**
# **Data cleaning means fixing bad data in your data set.**
#
# **Bad data could be:
# -Empty cells,
# -Data in wrong format,
# -Wrong data,
# -Duplicates**

# %% [markdown]
# **-Return the Data Frame with empty cells:**

# %%
import pandas as pd

df = pd.read_csv('data_pulse.csv')

# %%
df
# Out:
#     index  Duration        Date  Pulse  Maxpulse  Calories
# 0       0        60   20/12/01'    110       143    409.60
# 1       1        60   20/12/02'    117       145    402.30
# 2       2        60   20/12/03'    103       150    380.50
# 3       3        45   20/12/04'    109       160    368.30
# 4       4        45   20/12/05'    117       134    353.80
# 5       5        60   20/12/06'    102       155    339.20
# 6       6        60   20/12/07'    110       154    324.70
# 7       7       450   20/12/08'    104       135    310.16
# 8       8        30   20/12/09'    109       140    415.20
# 9       9        60   20/12/10'     98       155    350.80
# 10     10        60   20/12/11'    100       145    410.50
# 11     11        60   20/12/12'    102       139    387.40
# 12     12        60   20/12/13'    102       141    385.10
# 13     13        60   20/12/14'    107       142    382.70
# 14     14        60   20/12/15'    110       145    380.40
# ...

# %% [markdown]
# **-Return a new Data Frame with no empty cells:**

# %%
import pandas as pd

df = pd.read_csv('data_pulse.csv')

new_df = df.dropna()

print(new_df.to_string())
# Out:
#     index  Duration        Date  Pulse  Maxpulse  Calories
# 0       0        60   20/12/01'    110       143    409.60
# 1       1        60   20/12/02'    117       145    402.30
# 2       2        60   20/12/03'    103       150    380.50
# 3       3        45   20/12/04'    109       160    368.30
# 4       4        45   20/12/05'    117       134    353.80
# 5       5        60   20/12/06'    102       155    339.20
# 6       6        60   20/12/07'    110       154    324.70
# 7       7       450   20/12/08'    104       135    310.16
# 8       8        30   20/12/09'    109       140    415.20
# 9       9        60   20/12/10'     98       155    350.80
# 10     10        60   20/12/11'    100       145    410.50
# 11     11        60   20/12/12'    102       139    387.40
# 12     12        60   20/12/13'    102       141    385.10
# 13     13        60   20/12/14'    107       142    382.70
# 14     14        60   20/12/15'    110       145    380.40
# ...

# %%
import pandas as pd

df = pd.read_csv('data_pulse.csv')

new_df = df.dropna()

# %%
new_df
# Out:
#     index  Duration        Date  Pulse  Maxpulse  Calories
# 0       0        60   20/12/01'    110       143    409.60
# 1       1        60   20/12/02'    117       145    402.30
# 2       2        60   20/12/03'    103       150    380.50
# 3       3        45   20/12/04'    109       160    368.30
# 4       4        45   20/12/05'    117       134    353.80
# 5       5        60   20/12/06'    102       155    339.20
# 6       6        60   20/12/07'    110       154    324.70
# 7       7       450   20/12/08'    104       135    310.16
# 8       8        30   20/12/09'    109       140    415.20
# 9       9        60   20/12/10'     98       155    350.80
# 10     10        60   20/12/11'    100       145    410.50
# 11     11        60   20/12/12'    102       139    387.40
# 12     12        60   20/12/13'    102       141    385.10
# 13     13        60   20/12/14'    107       142    382.70
# 14     14        60   20/12/15'    110       145    380.40
# ...

# %% [markdown]
# **If you want to change the original DataFrame, use the inplace = True argument:**

# %% [markdown]
# **-Remove all rows with NULL values:**

# %%
import pandas as pd

df = pd.read_csv('data_pulse.csv')

df.dropna(inplace = True)

print(df.to_string())
# Out:
#     index  Duration        Date  Pulse  Maxpulse  Calories
# 0       0        60   20/12/01'    110       143    409.60
# 1       1        60   20/12/02'    117       145    402.30
# 2       2        60   20/12/03'    103       150    380.50
# 3       3        45   20/12/04'    109       160    368.30
# 4       4        45   20/12/05'    117       134    353.80
# 5       5        60   20/12/06'    102       155    339.20
# 6       6        60   20/12/07'    110       154    324.70
# 7       7       450   20/12/08'    104       135    310.16
# 8       8        30   20/12/09'    109       140    415.20
# 9       9        60   20/12/10'     98       155    350.80
# 10     10        60   20/12/11'    100       145    410.50
# 11     11        60   20/12/12'    102       139    387.40
# 12     12        60   20/12/13'    102       141    385.10
# 13     13        60   20/12/14'    107       142    382.70
# 14     14        60   20/12/15'    110       145    380.40
# ...

# %%
df = pd.read_csv('data_pulse.csv')

df.dropna(inplace = True)

# %%
print(df.to_string())
# Out:
#     index  Duration        Date  Pulse  Maxpulse  Calories
# 0       0        60   20/12/01'    110       143    409.60
# 1       1        60   20/12/02'    117       145    402.30
# 2       2        60   20/12/03'    103       150    380.50
# 3       3        45   20/12/04'    109       160    368.30
# 4       4        45   20/12/05'    117       134    353.80
# 5       5        60   20/12/06'    102       155    339.20
# 6       6        60   20/12/07'    110       154    324.70
# 7       7       450   20/12/08'    104       135    310.16
# 8       8        30   20/12/09'    109       140    415.20
# 9       9        60   20/12/10'     98       155    350.80
# 10     10        60   20/12/11'    100       145    410.50
# 11     11        60   20/12/12'    102       139    387.40
# 12     12        60   20/12/13'    102       141    385.10
# 13     13        60   20/12/14'    107       142    382.70
# 14     14        60   20/12/15'    110       145    380.40
# ...

# %% [markdown]
# **-Some basic information**

# %%
df.head()
# Out:
#    index  Duration       Date  Pulse  Maxpulse  Calories
# 0      0        60  20/12/01'    110       143     409.6
# 1      1        60  20/12/02'    117       145     402.3
# 2      2        60  20/12/03'    103       150     380.5
# 3      3        45  20/12/04'    109       160     368.3
# 4      4        45  20/12/05'    117       134     353.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 0 to 31
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     29 non-null     int64
#  1   Duration  29 non-null     int64
#  2   Date      29 non-null     object
#  3   Pulse     29 non-null     int64
#  4   Maxpulse  29 non-null     int64
#  5   Calories  29 non-null     float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 1.6+ KB

# %%
df.isnull().any()
# Out:
# index       False
# Duration    False
# Date        False
# Pulse       False
# Maxpulse    False
# Calories    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# index       0
# Duration    0
# Date        0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
df.shape
# Out:
# (29, 6)

# %% [markdown]
# # Replace Empty Values

# %% [markdown]
# **Another way of dealing with empty cells is to insert a new value instead.**
#
# **-This way you do not have to delete entire rows just because of some empty cells.**
#
# **-The fillna() method allows us to replace empty cells with a value:**

# %% [markdown]
# **Example:
# Replace NULL values with the number 130:**

# %%
import pandas as pd

df = pd.read_csv('data_pulse.csv')

df.fillna(130, inplace = True)

# %%
df
# Out:
#     index  Duration        Date  Pulse  Maxpulse  Calories
# 0       0        60   20/12/01'    110       143    409.60
# 1       1        60   20/12/02'    117       145    402.30
# 2       2        60   20/12/03'    103       150    380.50
# 3       3        45   20/12/04'    109       160    368.30
# 4       4        45   20/12/05'    117       134    353.80
# 5       5        60   20/12/06'    102       155    339.20
# 6       6        60   20/12/07'    110       154    324.70
# 7       7       450   20/12/08'    104       135    310.16
# 8       8        30   20/12/09'    109       140    415.20
# 9       9        60   20/12/10'     98       155    350.80
# 10     10        60   20/12/11'    100       145    410.50
# 11     11        60   20/12/12'    102       139    387.40
# 12     12        60   20/12/13'    102       141    385.10
# 13     13        60   20/12/14'    107       142    382.70
# 14     14        60   20/12/15'    110       145    380.40
# ...

# %% [markdown]
# # Replace Only For Specified Columns

# %% [markdown]
# **-Replace NULL values in the "Calories" columns with the number 130:**

# %%
import pandas as pd

df = pd.read_csv('data_pulse.csv')

df["Calories"].fillna(130, inplace = True)

# %%
df
# Out:
#     index  Duration        Date  Pulse  Maxpulse  Calories
# 0       0        60   20/12/01'    110       143    409.60
# 1       1        60   20/12/02'    117       145    402.30
# 2       2        60   20/12/03'    103       150    380.50
# 3       3        45   20/12/04'    109       160    368.30
# 4       4        45   20/12/05'    117       134    353.80
# 5       5        60   20/12/06'    102       155    339.20
# 6       6        60   20/12/07'    110       154    324.70
# 7       7       450   20/12/08'    104       135    310.16
# 8       8        30   20/12/09'    109       140    415.20
# 9       9        60   20/12/10'     98       155    350.80
# 10     10        60   20/12/11'    100       145    410.50
# 11     11        60   20/12/12'    102       139    387.40
# 12     12        60   20/12/13'    102       141    385.10
# 13     13        60   20/12/14'    107       142    382.70
# 14     14        60   20/12/15'    110       145    380.40
# ...

# %% [markdown]
# # Replace Using Mean, Median, or Mode

# %% [markdown]
# **-Calculate the MEAN, and replace any empty values with it:**

# %%
x = df["Calories"].mean()

df["Calories"].fillna(x, inplace = True)

# %%
df
# Out:
#     index  Duration        Date  Pulse  Maxpulse  Calories
# 0       0        60   20/12/01'    110       143    409.60
# 1       1        60   20/12/02'    117       145    402.30
# 2       2        60   20/12/03'    103       150    380.50
# 3       3        45   20/12/04'    109       160    368.30
# 4       4        45   20/12/05'    117       134    353.80
# 5       5        60   20/12/06'    102       155    339.20
# 6       6        60   20/12/07'    110       154    324.70
# 7       7       450   20/12/08'    104       135    310.16
# 8       8        30   20/12/09'    109       140    415.20
# 9       9        60   20/12/10'     98       155    350.80
# 10     10        60   20/12/11'    100       145    410.50
# 11     11        60   20/12/12'    102       139    387.40
# 12     12        60   20/12/13'    102       141    385.10
# 13     13        60   20/12/14'    107       142    382.70
# 14     14        60   20/12/15'    110       145    380.40
# ...

# %%
df.Calories.mean()
# Out:
# 361.5065517241379

# %%
x = df["Calories"].mean()

# %%
x
# Out:
# 361.5065517241379

# %%
df.Calories.mean()
df["Calories"].fillna(x, inplace = True)

# %%
df
# Out:
#     index  Duration        Date  Pulse  Maxpulse  Calories
# 0       0        60   20/12/01'    110       143    409.60
# 1       1        60   20/12/02'    117       145    402.30
# 2       2        60   20/12/03'    103       150    380.50
# 3       3        45   20/12/04'    109       160    368.30
# 4       4        45   20/12/05'    117       134    353.80
# 5       5        60   20/12/06'    102       155    339.20
# 6       6        60   20/12/07'    110       154    324.70
# 7       7       450   20/12/08'    104       135    310.16
# 8       8        30   20/12/09'    109       140    415.20
# 9       9        60   20/12/10'     98       155    350.80
# 10     10        60   20/12/11'    100       145    410.50
# 11     11        60   20/12/12'    102       139    387.40
# 12     12        60   20/12/13'    102       141    385.10
# 13     13        60   20/12/14'    107       142    382.70
# 14     14        60   20/12/15'    110       145    380.40
# ...

# %%
df.Calories.median()
# Out:
# 368.3

# %%
df.Calories.median()
df["Calories"].fillna(x, inplace = True)

# %%
df
# Out:
#     index  Duration        Date  Pulse  Maxpulse  Calories
# 0       0        60   20/12/01'    110       143    409.60
# 1       1        60   20/12/02'    117       145    402.30
# 2       2        60   20/12/03'    103       150    380.50
# 3       3        45   20/12/04'    109       160    368.30
# 4       4        45   20/12/05'    117       134    353.80
# 5       5        60   20/12/06'    102       155    339.20
# 6       6        60   20/12/07'    110       154    324.70
# 7       7       450   20/12/08'    104       135    310.16
# 8       8        30   20/12/09'    109       140    415.20
# 9       9        60   20/12/10'     98       155    350.80
# 10     10        60   20/12/11'    100       145    410.50
# 11     11        60   20/12/12'    102       139    387.40
# 12     12        60   20/12/13'    102       141    385.10
# 13     13        60   20/12/14'    107       142    382.70
# 14     14        60   20/12/15'    110       145    380.40
# ...

# %%
df.Calories.mode()
# Out:
# 0     258.90
# 1     288.80
# 2     310.16
# 3     318.70
# 4     324.70
# 5     339.20
# 6     348.60
# 7     350.80
# 8     353.80
# 9     354.50
# 10    356.90
# 11    359.26
# 12    361.60
# 13    366.30
# 14    368.30
# 15    368.60
# 16    371.01
# 17    373.30
# 18    378.06
# 19    378.50
# 20    380.40
# 21    380.50
# 22    382.70
# 23    385.10
# 24    387.40
# 25    402.30
# 26    409.60
# 27    410.50
# 28    415.20
# Name: Calories, dtype: float64

# %%
df.Calories.mode()
df["Calories"].fillna(x, inplace = True)

# %%
df
# Out:
#     index  Duration        Date  Pulse  Maxpulse  Calories
# 0       0        60   20/12/01'    110       143    409.60
# 1       1        60   20/12/02'    117       145    402.30
# 2       2        60   20/12/03'    103       150    380.50
# 3       3        45   20/12/04'    109       160    368.30
# 4       4        45   20/12/05'    117       134    353.80
# 5       5        60   20/12/06'    102       155    339.20
# 6       6        60   20/12/07'    110       154    324.70
# 7       7       450   20/12/08'    104       135    310.16
# 8       8        30   20/12/09'    109       140    415.20
# 9       9        60   20/12/10'     98       155    350.80
# 10     10        60   20/12/11'    100       145    410.50
# 11     11        60   20/12/12'    102       139    387.40
# 12     12        60   20/12/13'    102       141    385.10
# 13     13        60   20/12/14'    107       142    382.70
# 14     14        60   20/12/15'    110       145    380.40
# ...

# %%
import pandas as pd

df = pd.read_csv('data_pulse.csv')

x = df["Calories"].mode()[0]

df["Calories"].fillna(x, inplace = True)

# %%
df
# Out:
#     index  Duration        Date  Pulse  Maxpulse  Calories
# 0       0        60   20/12/01'    110       143    409.60
# 1       1        60   20/12/02'    117       145    402.30
# 2       2        60   20/12/03'    103       150    380.50
# 3       3        45   20/12/04'    109       160    368.30
# 4       4        45   20/12/05'    117       134    353.80
# 5       5        60   20/12/06'    102       155    339.20
# 6       6        60   20/12/07'    110       154    324.70
# 7       7       450   20/12/08'    104       135    310.16
# 8       8        30   20/12/09'    109       140    415.20
# 9       9        60   20/12/10'     98       155    350.80
# 10     10        60   20/12/11'    100       145    410.50
# 11     11        60   20/12/12'    102       139    387.40
# 12     12        60   20/12/13'    102       141    385.10
# 13     13        60   20/12/14'    107       142    382.70
# 14     14        60   20/12/15'    110       145    380.40
# ...

# %%
df.Calories.mode()
# Out:
# 0    258.9
# Name: Calories, dtype: float64

# %% [markdown]
# # Pandas - Cleaning Data of Wrong Format

# %% [markdown]
# **Data of Wrong Format
# -Cells with data of wrong format can make it difficult, or even impossible, to analyze data.**

# %%
import pandas as pd

df = pd.read_csv('data_pulse.csv')

df['Date'] = pd.to_datetime(df['Date'])

print(df.to_string())
# Out:
#     index  Duration       Date  Pulse  Maxpulse  Calories
# 0       0        60 2001-12-20    110       143    409.60
# 1       1        60 2002-12-20    117       145    402.30
# 2       2        60 2003-12-20    103       150    380.50
# 3       3        45 2004-12-20    109       160    368.30
# 4       4        45 2005-12-20    117       134    353.80
# 5       5        60 2006-12-20    102       155    339.20
# 6       6        60 2007-12-20    110       154    324.70
# 7       7       450 2008-12-20    104       135    310.16
# 8       8        30 2009-12-20    109       140    415.20
# 9       9        60 2010-12-20     98       155    350.80
# 10     10        60 2011-12-20    100       145    410.50
# 11     11        60 2012-12-20    102       139    387.40
# 12     12        60 2013-12-20    102       141    385.10
# 13     13        60 2014-12-20    107       142    382.70
# 14     14        60 2015-12-20    110       145    380.40
# ...

# %% [markdown]
# **Removing Rows:- Remove rows with a NULL value in the "Date" column:**

# %%
df.dropna(subset=['Date'], inplace = True)

# %%
df
# Out:
#     index  Duration       Date  Pulse  Maxpulse  Calories
# 0       0        60 2001-12-20    110       143    409.60
# 1       1        60 2002-12-20    117       145    402.30
# 2       2        60 2003-12-20    103       150    380.50
# 3       3        45 2004-12-20    109       160    368.30
# 4       4        45 2005-12-20    117       134    353.80
# 5       5        60 2006-12-20    102       155    339.20
# 6       6        60 2007-12-20    110       154    324.70
# 7       7       450 2008-12-20    104       135    310.16
# 8       8        30 2009-12-20    109       140    415.20
# 9       9        60 2010-12-20     98       155    350.80
# 10     10        60 2011-12-20    100       145    410.50
# 11     11        60 2012-12-20    102       139    387.40
# 12     12        60 2013-12-20    102       141    385.10
# 13     13        60 2014-12-20    107       142    382.70
# 14     14        60 2015-12-20    110       145    380.40
# ...

# %% [markdown]
# # Pandas - Fixing Wrong Data

# %% [markdown]
# **Wrong Data:- "Wrong data" does not have to be "empty cells" or "wrong format", it can just be wrong, like if someone registered "199" instead of "1.99".**

# %% [markdown]
# **Replacing Values:- One way to fix wrong values is to replace them with something else.**

# %%
df.loc[7, 'Duration'] = 45

# %%
df
# Out:
#     index  Duration       Date  Pulse  Maxpulse  Calories
# 0       0        60 2001-12-20    110       143    409.60
# 1       1        60 2002-12-20    117       145    402.30
# 2       2        60 2003-12-20    103       150    380.50
# 3       3        45 2004-12-20    109       160    368.30
# 4       4        45 2005-12-20    117       134    353.80
# 5       5        60 2006-12-20    102       155    339.20
# 6       6        60 2007-12-20    110       154    324.70
# 7       7        45 2008-12-20    104       135    310.16
# 8       8        30 2009-12-20    109       140    415.20
# 9       9        60 2010-12-20     98       155    350.80
# 10     10        60 2011-12-20    100       145    410.50
# 11     11        60 2012-12-20    102       139    387.40
# 12     12        60 2013-12-20    102       141    385.10
# 13     13        60 2014-12-20    107       142    382.70
# 14     14        60 2015-12-20    110       145    380.40
# ...

# %% [markdown]
# **Removing Rows:- Another way of handling wrong data is to remove the rows that contains wrong data.**

# %% [markdown]
# **-Delete rows where "Duration" is higher than 120:**

# %%
for x in df.index:
  if df.loc[x, "Duration"] > 120:
    df.drop(x, inplace = True)

# %%
df
# Out:
#     index  Duration       Date  Pulse  Maxpulse  Calories
# 0       0        60 2001-12-20    110       143    409.60
# 1       1        60 2002-12-20    117       145    402.30
# 2       2        60 2003-12-20    103       150    380.50
# 3       3        45 2004-12-20    109       160    368.30
# 4       4        45 2005-12-20    117       134    353.80
# 5       5        60 2006-12-20    102       155    339.20
# 6       6        60 2007-12-20    110       154    324.70
# 7       7        45 2008-12-20    104       135    310.16
# 8       8        30 2009-12-20    109       140    415.20
# 9       9        60 2010-12-20     98       155    350.80
# 10     10        60 2011-12-20    100       145    410.50
# 11     11        60 2012-12-20    102       139    387.40
# 12     12        60 2013-12-20    102       141    385.10
# 13     13        60 2014-12-20    107       142    382.70
# 14     14        60 2015-12-20    110       145    380.40
# ...

# %% [markdown]
# # Pandas - Removing Duplicates

# %% [markdown]
# **Discovering Duplicates:- Duplicate rows are rows that have been registered more than one time.**

# %% [markdown]
# **-Returns True for every row that is a duplicate, othwerwise False:**

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %% [markdown]
# **Removing Duplicates:- To remove duplicates, use the drop_duplicates() method.**

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#     index  Duration       Date  Pulse  Maxpulse  Calories
# 0       0        60 2001-12-20    110       143    409.60
# 1       1        60 2002-12-20    117       145    402.30
# 2       2        60 2003-12-20    103       150    380.50
# 3       3        45 2004-12-20    109       160    368.30
# 4       4        45 2005-12-20    117       134    353.80
# 5       5        60 2006-12-20    102       155    339.20
# 6       6        60 2007-12-20    110       154    324.70
# 7       7        45 2008-12-20    104       135    310.16
# 8       8        30 2009-12-20    109       140    415.20
# 9       9        60 2010-12-20     98       155    350.80
# 10     10        60 2011-12-20    100       145    410.50
# 11     11        60 2012-12-20    102       139    387.40
# 12     12        60 2013-12-20    102       141    385.10
# 13     13        60 2014-12-20    107       142    382.70
# 14     14        60 2015-12-20    110       145    380.40
# ...
